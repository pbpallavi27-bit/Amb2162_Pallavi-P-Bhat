# %% [markdown]
# **AMB2162_PALLAVI P BHAT**

# %%
for i in range (20,55,6):
  print(i)
# Out:
# 20
# 26
# 32
# 38
# 44
# 50

# %%
from binascii import hexlify
a= 10
print (type(a))

a=10.5
print(type(a))

a=(10,20,30)
print(type(a))
print(a)

a=[10,20,30]
print(type(a))
print(a)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'tuple'>
# (10, 20, 30)
# <class 'list'>
# [10, 20, 30]

# %%
a=10
print("value of a is ",a)
print(type(a))
# Out:
# value of a is  10
# <class 'int'>

# %%
a=10
b=20
print ("valueof a and b are",a,b)
# Out:
# valueof a and b are 10 20

# %%
a=10
b=20
print("value of a and b {} and {}".format(a,b))
# Out:
# value of a and b 10 and 20

# %%
a=10
b=20
print("value of a and b {0} and {1}".format(a,b))
# Out:
# value of a and b 10 and 20

# %%
# Simple AI Decision System for Irrigation
# This demonstrates how AI "thinks" about farming decisions

def irrigation_advisor(soil_moisture, temperature, forecast_rain):
    """
    A rule-based AI system for irrigation decisions.
    This mimics how AI processes multiple factors.

    Parameters:
    - soil_moisture: percentage (0-100)
    - temperature: degrees Celsius
    - forecast_rain: True/False
    """

    # AI "reasoning" - considering multiple factors
    if soil_moisture < 30:
        if forecast_rain:
            return "⏳ Wait - Rain expected. Soil is dry but rain will help."
        else:
            return "💧 IRRIGATE NOW - Soil critically dry, no rain expected."

    elif soil_moisture < 60:
        if temperature > 35:
            return "💧 IRRIGATE - High temp causing rapid evaporation."
        else:
            return "✅ OKAY - Moisture adequate for now."

    else:
        return "🛑 NO IRRIGATION NEEDED - Soil has enough moisture."

# Test the AI advisor
print("=== Smart Irrigation Advisor ===")
print(irrigation_advisor(25, 32, False))  # Dry soil, no rain
print(irrigation_advisor(25, 32, True))   # Dry soil, rain coming
print(irrigation_advisor(45, 38, False))  # Medium moisture, hot day
print(irrigation_advisor(75, 28, False))  # Good moisture
# Out:
# === Smart Irrigation Advisor ===
# 💧 IRRIGATE NOW - Soil critically dry, no rain expected.
# ⏳ Wait - Rain expected. Soil is dry but rain will help.
# 💧 IRRIGATE - High temp causing rapid evaporation.
# 🛑 NO IRRIGATION NEEDED - Soil has enough moisture.

# %%
#inverting the values
hi="namaste"
print("Dear Madam {1},{0} {2}".format("my name",hi,"is PALLAVI"))
# Out:
# Dear Madam namaste,my name is PALLAVI

# %%
print("Today is {0}. But we didn't get {1}.\
because of {2} .So we chilling in {3}"\
      .format("chritsmas eve","holiday","AIML classes","computer lab"))
# Out:
# Today is chritsmas eve. But we didn't get holiday.because of AIML classes .So we chilling in computer lab

# %%
a=int(input("enter a number"))
print(a)
print(type(a))
# Out:
# enter a number4
# 4
# <class 'int'>

# %%
a=float(input("enter yor password"))
print(a)
print(type(a))
# Out:
# enter yor password90.0976
# 90.0976
# <class 'float'>

# %%
#program to read 2 numbers from the user print the product along with the numbers
a=int(input("enter the number"))
b=int(input ("enter 2nd number"))
c=a*b
print("product of {} and {} is {}".format(a,b,c))
# Out:
# enter the number67
# enter 2nd number87
# product of 67 and 87 is 5829

# %%
#program to read the name and age of a person and print the age after 10 years along with name
a=str(input("Enter your good name"))
b=int(input("Enter your age"))
c=b+10
print("{0}  YOUR AGE AFTER 10 YERAS IS  {1}".format(a,c))
# Out:
# Enter your good name NIRMALA
# Enter your age55
#  NIRMALA  YOUR AGE AFTER 10 YERAS IS  65
