# %% [markdown]
# **AMB2162_PALLAVI P BHAT**

# %%
# PROGRAM TO ADD NUMBERS

# %%
a=10
b=20
if a>b:
  print("a is greater than b")
else:
  print(" b is greater than a")
# Out:
#  b is greater than a

# %%
age=18
b=18
if age>=b:
  print("AGE IS ELIGIBLE FOR VOTING")
else:
  print("AGE IS NOT ELIGIBLE")
# Out:
# AGE IS ELIGIBLE FOR VOTING

# %%
num=0
if num>0:
  print("num is positive")
elif num<0:
  print("num is negative")
else:
  print("num is 0")
# Out:
# num is 0

# %%
m=3
if m>=9:
  print("passed")
  print("has the grade A")
elif m>=7 and m<9:
  print("  passed")
  print (" grade B")
elif m>=5:
  print ("grade C")
else:
  print("FAIL")
# Out:
# FAIL

# %%
num=26
if num%2==0:
  print("EVEN")
else:
  print("ODD")
# Out:
# EVEN

# %%
#write a program to read a number and check whether the number is divisible by 5 and 7
a=int(input(" ENTER THE NUMBER"))
if(a%5==0 and a%7==0):
  print("num is divisible by 5 and 7")
elif(a%5==0):
  print("num is divisbile by 5")
elif(a%7==0):
  print("num is divisible by 7")
else:
  print("num is not divisible by 5 or 7")
# Out:
#  ENTER THE NUMBER35
# num is divisible by 5 and 7

# %%
#write a program to read a radius of the circle and also give an option to the user to calculate
# area of circle or perimeter of the circle if user enters 1 display area if enters 2 display the perimeter
a=int(input (" ENTER THE RADIUS in centimeter"))
ch=int(input("enter 1 for AREA , 2 for PERIMETER"))
c=3.14*a*a
d=2*3.14*a
if(ch==1):
  print(c)
elif(ch==2):
  print(d)
else:
  print(" ENTER VALID NUMBER ")
# Out:
#  ENTER THE RADIUS in centimeter 7
# enter 1 for AREA , 2 for PERIMETER5
#  ENTER VALID NUMBER

# %%
#program to print a maximum of two numbers
a=int(input("enter the number"))
b=int(input(" enter the 2nd number"))
if(a>b):
  print("{} is greater than {}".format(a,b))
elif(b>a):
  print("{} is greater than {}".format(b,a))
else:
  print("{}={}".format (a,b))
# Out:
# enter the number0
#  enter the 2nd number0
# 0=0
