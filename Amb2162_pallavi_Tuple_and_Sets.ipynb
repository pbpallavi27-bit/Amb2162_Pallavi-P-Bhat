# %% [markdown]
# Data Structures in Python - Tuple and Sets
#
# #### Topics
# 3. Data Structures in Python - Tuple
# 4. Data Structures in Python - Sets
#
# ##### Note:
# 1. First Clean the Evironment (Go to "Kernel" Menu --> "Restart & Clean Output"
# 2. To execute the code --> Click on a cell and press cntrl + enter key

# %%
list1=[10,20,'hi',40]   
print(list1)
print(type(list1))  # indexes will be numbers which start from 0 step 1
# Out:
# [10, 20, 'hi', 40]
# <class 'list'>

# %%
dict1={'first':10,'second':20,'third':30}
print(dict1)
print(type(dict1))
# Out:
# {'first': 10, 'second': 20, 'third': 30}
# <class 'dict'>

# %%
print(dict1.keys())
print(dict1.values())
# Out:
# dict_keys(['first', 'second', 'third'])
# dict_values([10, 20, 30])

# %% [markdown]
# # 1: Data Structure - Tuple

# %% [markdown]
# ### 1.1: Tuple declaration

# %%
# Method 1

T = ("Pratham", 'Sharma', 3.14, 3)

print ("T                  -->", T)
print ("Number of elements -->", len(T))
print ("Type of Object     -->", type(T))
# Out:
# T                  --> ('Pratham', 'Sharma', 3.14, 3)
# Number of elements --> 4
# Type of Object     --> <class 'tuple'>

# %%
# Method 2

T = tuple(["Pratham", 'Sharma', 3.14, 3])   # Convert list to tuple
#T = tuple(("Pratham", 'Sharma', 3.14, 3))  # Also Works

print ("T                  -->", T)
print ("Number of elements -->", len(T))
print ("Type of Object     -->", type(T))
# Out:
# T                  --> ('Pratham', 'Sharma', 3.14, 3)
# Number of elements --> 4
# Type of Object     --> <class 'tuple'>

# %% [markdown]
# ### 1.2: Tuple with one item

# %%
# Example 1: Tuple with one item

T = ("Pratham",)            # atleast one comma is must

print ("T                  -->", T)
print ("Number of elements -->", len(T))
print ("Type of Object     -->", type(T))
# Out:
# T                  --> ('Pratham',)
# Number of elements --> 1
# Type of Object     --> <class 'tuple'>

# %%
# Example 2: This is not a Tuple. It is a string

T = ("Pratham")         # Without comma, it is a string

print ("T                  -->", T)
print ("Number of elements -->", len(T))
print ("Type of Object     -->", type(T))
# Out:
# T                  --> Pratham
# Number of elements --> 7
# Type of Object     --> <class 'str'>

# %% [markdown]
# ### 1.3: Tuple iteration using while loop

# %%
T = ("Pratham", 'Sharma', 3.14, 3)
print ("T -->", T)

i = 0
print ("")
while i < len(T): 
    print (T[i])
    i += 1
# Out:
# T --> ('Pratham', 'Sharma', 3.14, 3)
#
# Pratham
# Sharma
# 3.14
# 3

# %% [markdown]
# ### 1.4: Tuple iteration using for loop

# %%
# Example 1:

T = ("Pratham", 'Sharma', 3.14, 3)
print ("T -->", T)

print ("")
for i in range( len(T)):   # refereing to the indexes
    print (T[i])
# Out:
# T --> ('Pratham', 'Sharma', 3.14, 3)
#
# Pratham
# Sharma
# 3.14
# 3

# %%
# Example 2:

T = ("Pratham", 'Sharma', 3.14, 3)
print ("T -->", T)

print ("")
for s in T:         #refereing to the elements
    print (s)
# Out:
# T --> ('Pratham', 'Sharma', 3.14, 3)
#
# Pratham
# Sharma
# 3.14
# 3

# %% [markdown]
# ### 1.5: Accessing/Selecting Tuple item

# %%
# Example 1:
T = (3, 6, 9, 12, 5, 3, 2)
     0  1  2   3  4  5  6
    -7 -6 -5  -4 -3 -2 -1

print ("T     -->", T)

print ("T[1]  -->", T[1])  #6
print ("T[2]  -->", T[2])  #9
print ("T[-1] -->", T[-1]) #2
print ("T[-2] -->", T[-2]) #3
# Out:
# T     --> (3, 6, 9, 12, 5, 3, 2)
# T[1]  --> 6
# T[2]  --> 9
# T[-1] --> 2
# T[-2] --> 3

# %%
# Example 2:

T = (3, 6, 9, 12, 5, 3, 2)
        #      -4   -3   -2    -1
print ("T        -->", T)

print ("T[1:3]   -->", T[1:3])   #6 9
print ("T[2:]    -->", T[2:])    # 9 12 5 3 2
print ("T[2:5]   -->", T[2:5])   # 9 12 5
print ("T[:2]    -->", T[:2])    # 3 6
print ("T[:-1]   -->", T[:-1])   # 3 6 9 12 5 3
print ("T[-4:-1] -->", T[-4:-1]) # 12 5 3
# Out:
# T        --> (3, 6, 9, 12, 5, 3, 2)
# T[1:3]   --> (6, 9)
# T[2:]    --> (9, 12, 5, 3, 2)
# T[2:5]   --> (9, 12, 5)
# T[:2]    --> (3, 6)
# T[:-1]   --> (3, 6, 9, 12, 5, 3)
# T[-4:-1] --> (12, 5, 3)

# %%
T = (3, 6, 9, 12, 5, 3, 2)
        #      -4   -3   -2    -1
print ("T        -->", T)

print ("T[1:3]   -->", T[1:3])   #
print ("T[2:]    -->", T[2:])    # 
print ("T[2:5]   -->", T[2:5])   # 
print ("T[:2]    -->", T[:2])    #
print ("T[:-1]   -->", T[:-1])   # 
print ("T[-4:-1] -->", T[-4:-1])

# %%
# Example 3:

T = (3, 6, 9, 12, 5, 3, 2)
print ("T        -->", T)

print ("T[::1]   -->", T[::1])        # No change
print ("T[::-1]  -->", T[::-1])       # Reverse
print ("T[::-2]  -->", T[::-2])     #          
print ("T[::2]   -->", T[::2])
# Out:
# T        --> (3, 6, 9, 12, 5, 3, 2)
# T[::1]   --> (3, 6, 9, 12, 5, 3, 2)
# T[::-1]  --> (2, 3, 5, 12, 9, 6, 3)
# T[::-2]  --> (2, 5, 9, 3)
# T[::2]   --> (3, 9, 5, 2)

# %% [markdown]
# ### 1.6: Adding element to Tuple (Error)

# %%
T = ("Pratham", 'Sharma', 3.14, 3)
print ("T -->", T)

T[2] = 900               # Error; 'tuple' object does not support item assignment
print ("T -->", T)

#Tuples are unchangeable,immutable. We cannot add items to it.
# Out:
# T --> ('Pratham', 'Sharma', 3.14, 3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 4
#       1 T = ("Pratham", 'Sharma', 3.14, 3)
#       2 print ("T -->", T)
# ----> 4 T[2] = 900               # Error; 'tuple' object does not support item assignment
#       5 print ("T -->", T)
#       7 #Tuples are unchangeable,immutable. We cannot add items to it.
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### 1.7: Adding element to Tuple

# %%
T = ("Pratham", 'Sharma', 3.14, 3)
print ("T         -->", T)


#T.append(9.8)   # error - no attribute append
#T.insert(2, "Rahul")    # error - no insert method for tuple
#T.add(6)            # error - no add method for tuple
#del T[2]     # error - no delete method for tuple
#T.extend(9.8) # error - no extend method for tuple
# Out:
# T         --> ('Pratham', 'Sharma', 3.14, 3)
#
# After Add --> ('Pratham', 'Sharma', 3.14, 3)

# %%
# then how to add item to tuple?
# convert tuple to list, add item to list and convert back to tuple
T = ("Pratham", 'Sharma', 3.14, 3)
print ("T         -->", T)

T1 = list(T)
T1.append(9.8)
T = tuple(T1)

print ("")
print ("After Add -->", T)
# Out:
# T         --> ('Pratham', 'Sharma', 3.14, 3)
#
# After Add --> ('Pratham', 'Sharma', 3.14, 3, 9.8)

# %% [markdown]
# ### 1.8: Inserting element in Tuple

# %%
T = ("Pratham", 'Sharma', 3.14, 3)
print ("T            -->", T)

T1 = list(T)
T1.insert(2, "Rahul")
T = tuple(T1)

print ("After Insert -->", T)
# Out:
# T            --> ('Pratham', 'Sharma', 3.14, 3)
#
# After Insert --> ('Pratham', 'Sharma', 'Rahul', 3.14, 3)

# %% [markdown]
# ### 1.9: Deleting from Tuple

# %%
T = ("Pratham", 'Sharma', 3.14, 3)
print ("T            -->", T)

T1 = list(T)
print(type(T1))
del T1[1]
T = tuple(T1)

print ("")
print ("After Delete -->", T)
# Out:
# T            --> ('Pratham', 'Sharma', 3.14, 3)
#
# After Delete --> ('Pratham', 3.14, 3)

# %% [markdown]
# ### 1.10: Sum/Average of Tuple

# %%
T = (3, 6, 9, 12, 5, 3, 2)

print ("T       -->", T)
print ("Sum     -->", sum(T))
print ("Average -->", sum(T)/len(T))
print ("Average -->", sum(T)//len(T))
# Out:
# T       --> (3, 6, 9, 12, 5, 3, 2)
# Sum     --> 40
# Average --> 5.714285714285714
# Average --> 5

# %% [markdown]
# ### 1.11: Min/Max in the Tuple

# %%
# Example 1

T = (3, 6, 9, 12, 5, 3, 2)                # Integer Tuple
print ("T   -->", T)
print ("Max -->", max(T))
print ("Min -->", min(T))
# Out:
# T   --> (3, 6, 9, 12, 5, 3, 2)
# Max --> 12
# Min --> 2

# %% [markdown]
# ### 1.12: Searching in the Tuple

# %%
T = (3, 6, 9, 12, 5, 3, 2)
print ("T       -->", T)

print ("")
print ("6  in T -->", 6 in T)
print ("10 in T -->", 10 in T)
print ("12 in T -->", 12 in T)
# Out:
# T       --> (3, 6, 9, 12, 5, 3, 2)
#
# 6  in T --> True
# 10 in T --> False
# 12 in T --> True

# %% [markdown]
# ### 1.13: Merging Tuples

# %%
T1 = (3, 6, 9)
T2 = (12, 5, 3, 2)

print ("T1 -->", T1)
print ("T2 -->", T2)

T3 = T1 + T2
print ("T3 -->", T3)

T4 = T1 + T2 + T1 + T2
print ("T4 -->", T4)
# Out:
# T1 --> (3, 6, 9)
# T2 --> (12, 5, 3, 2)
# T3 --> (3, 6, 9, 12, 5, 3, 2)
# T4 --> (3, 6, 9, 12, 5, 3, 2, 3, 6, 9, 12, 5, 3, 2)

# %% [markdown]
# ### 1.14: Merging part of Tuples

# %%
T1 = (3, 6, 9)
T2 = (12, 5, 3, 2)

print ("T1 -->", T1)
print ("T2 -->", T2)

T3 = T1[1:2] + T2[1:3]
print ("T3 -->", T3)

T4 = T1[:-2] + T2[:-3]
print ("T4 -->", T4)
# Out:
# T1 --> (3, 6, 9)
# T2 --> (12, 5, 3, 2)
# T3 --> (6, 5, 3)
# T4 --> (3, 12)

# %% [markdown]
# ### 1.15: Get the index of an elements in Tuple

# %%
T = (3, 6, 9, 12, 5, 3, 2)
print ("T               -->", T)

print ("")
print ("Index of 9 in T -->", T.index(9))   
print ("Index of 2 in T -->", T.index(2))
print ("Index of 3 in T -->", T.index(3))
print ("Index of 7 in T -->", T.index(7))        # Error; 7 is not is Tuple  # last index is 6 and length is 7
# Out:
# T               --> (3, 6, 9, 12, 5, 3, 2)
#
# Index of 9 in T --> 2
# Index of 2 in T --> 6
# Index of 3 in T --> 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 8
#       6 print ("Index of 2 in T -->", T.index(2))
#       7 print ("Index of 3 in T -->", T.index(3))
# ----> 8 print ("Index of 7 in T -->", T.index(7))
#
# ValueError: tuple.index(x): x not in tuple

# %% [markdown]
# ### 1.16: Count element in Tuple

# %%
T = (3, 6, 9, 6, 5, 3, 2)
print ("T          -->", T)

print ("")
print ("T.count(3) -->", T.count(3))
print ("T.count(2) -->", T.count(2))
print ("T.count(5) -->", T.count(5))
print ("T.count(4) -->", T.count(4))
# Out:
# T          --> (3, 6, 9, 6, 5, 3, 2)
#
# T.count(3) --> 2
# T.count(2) --> 1
# T.count(5) --> 1
# T.count(4) --> 0

# %% [markdown]
# # 2: Data Structure - Sets

# %% [markdown]
# ### 2.1: Sets declaration

# %%
# Example 1

#list   []
#tuple ()
#sets {}
#dictionary {k:v}

S = {'E','A', 'B', 'E', 'F','E', 'F'}

print ("S                  -->", S)
print ("Number of elements -->", len(S))
print ("Type of Object     -->", type(S))
# Out:
# S                  --> {'B', 'E', 'F', 'A'}
# Number of elements --> 4
# Type of Object     --> <class 'set'>

# %%
# Example 2

S = set(['A', 'B', 'E', 'F','E', 'F' ])
# S = set(('A', 'B', 'E', 'F','E', 'F' )) # Also works

print ("S                  -->", S)
print ("Number of elements -->", len(S))
print ("Type of Object     -->", type(S))
# Out:
# S                  --> {'B', 'E', 'F', 'A'}
# Number of elements --> 4
# Type of Object     --> <class 'set'>

# %% [markdown]
# ### 2.2: Traverse set elements

# %%
S = {'A', 'B', 'E', 'F','E', 'F'}

print ("S -->", S)

print ("")
for k in S:
    print (k)
# Out:
# S --> {'B', 'E', 'F', 'A'}
#
# B
# E
# F
# A

# %% [markdown]
# ### 2.3: Set elements are unindexed

# %%
S = {'A', 'B', 'E', 'F','E', 'F'}

print ("S -->", S)

print (S[2])   # Error; 'set' object is not subscriptable
# Out:
# S --> {'B', 'E', 'F', 'A'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 5
#       1 S = {'A', 'B', 'E', 'F','E', 'F'}
#       3 print ("S -->", S)
# ----> 5 print (S[2])
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# ### 2.4: Adding element to Set using add()

# %%
S = set(['A', 'B', 'E', 'F' ])
print ("S                -->", S)

S.add("D")
print ("After Adding (D) -->", S)

S.add("D")
print ("After Adding (D) -->", S)    # No Change in Set

S.add("C")
print ("After Adding (C) -->", S)
# Out:
# S                --> {'B', 'E', 'F', 'A'}
# After Adding (D) --> {'B', 'F', 'A', 'D', 'E'}
# After Adding (D) --> {'B', 'F', 'A', 'D', 'E'}
# After Adding (C) --> {'B', 'F', 'A', 'D', 'C', 'E'}

# %% [markdown]
# ### 2.5: Adding element to Set using update()

# %%
# Once a set is created, we cannot change the items, but we can add new items.

#Example 1:
S1 = set(['A', 'B', 'E', 'F' ])
S2 = set(["D", "E", "F", "G" ])

print ("S1              -->", S1)
print ("S2              -->", S2)

S1.update(S2)                       #inserts the items in S2 into S1; Union

print ("\nAfter update S1 -->", S1)
# Out:
# S1              --> {'B', 'E', 'F', 'A'}
# S2              --> {'F', 'E', 'G', 'D'}
#
# After update S1 --> {'B', 'F', 'A', 'G', 'D', 'E'}

# %%
#Example 2:

S = set(['A', 'B', 'E', 'F' ])
print ("S              -->", S)

S.update(["F", "G", "H", "I"])

print ("After update S -->", S)
# Out:
# S              --> {'B', 'E', 'F', 'A'}
# After update S --> {'B', 'I', 'F', 'A', 'G', 'H', 'E'}

# %% [markdown]
# ### 2.6: Removing element from Set using remove()

# %%
S = set(['A', 'B', 'E', 'F' ])
print ("S                  -->", S)

S.remove("B")
print ("After removing (B) -->", S)

S.remove("E")
print ("After removing (E) -->", S)

S.remove("E")                           # Error
print ("After Adding (E) -->", S)

#Note: If the item does not exist, remove() will raise an exception
# Out:
# S                  --> {'B', 'E', 'F', 'A'}
# After removing (B) --> {'E', 'F', 'A'}
# After removing (E) --> {'F', 'A'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 10
#       7 S.remove("E")
#       8 print ("After removing (E) -->", S)
# ---> 10 S.remove("E")                           # Error
#      11 print ("After Adding (E) -->", S)
#
# KeyError: 'E'

# %% [markdown]
# ### 2.7: Removing element from Set using discard()

# %%
S = set(['A', 'B', 'E', 'F' ])
print ("S                 -->", S)

S.discard("B")
print ("After discard (B) -->", S)

S.discard("E")
print ("After discard (E) -->", S)

S.discard("E")                         # No Error
print ("After discard (E) -->", S)

#Note: If the item does not exist, discard() will NOT raise an exception
# Out:
# S                 --> {'B', 'E', 'F', 'A'}
# After discard (B) --> {'E', 'F', 'A'}
# After discard (E) --> {'F', 'A'}
# After discard (E) --> {'F', 'A'}

# %% [markdown]
# ### 2.8: Removing element from Set using pop()

# %%
S = set(['A', 'B' ])
print ("S         -->", S)

S.pop()
print ("After pop -->", S)

S.pop()
print ("After pop -->", S)

S.pop()                       # Error; Set is empty; Under flow
print ("After pop -->", S)


#Note: If set is empty, pop() will raise an exception
# Out:
# S         --> {'B', 'A'}
# After pop --> {'A'}
# After pop --> set()
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 10
#       7 S.pop()
#       8 print ("After pop -->", S)
# ---> 10 S.pop()                       # Error; Set is empty; Under flow
#      11 print ("After pop -->", S)
#
# KeyError: 'pop from an empty set'

# %% [markdown]
# ### 2.9: Clear elements in Set (Deleting all elements)

# %%
S = set(['A', 'B', 'E', 'F' ])
print ("S               -->", S)

S.clear()            # Deleting all elements
print ("Set after clear -->", S)
# Out:
# S               --> {'B', 'E', 'F', 'A'}
# Set after clear --> set()

# %% [markdown]
# ### 2.10: Deleting Set

# %%
S = set(['A', 'B', 'E', 'F' ])
print ("S               -->", S)

del S
print ("Set after delete -->", S)   # Error
                                     # Set is deleted and still want to print
                                     # Exception should me handle
# Out:
# S               --> {'B', 'E', 'F', 'A'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 5
#       2 print ("S               -->", S)
#       4 del S
# ----> 5 print ("Set after delete -->", S)
#
# NameError: name 'S' is not defined

# %% [markdown]
# ### 2.11: Sum/Average all values of Set

# %%
S = {1, 3, 5, 6, 8, 9}

print ("S       -->", S)
print ("Sum     -->", sum(S))
print ("Average -->", sum(S)/len(S))
print ("Average -->", sum(S)//len(S))
# Out:
# S       --> {1, 3, 5, 6, 8, 9}
# Sum     --> 32
# Average --> 5.333333333333333
# Average --> 5

# %% [markdown]
# ### 2.12: Min/Max values in the Set

# %%
# Example 1
S = {3, 6, 9, 12, 5, 3, 2}                # Integer Set

print ("S   -->", S)
print ("Max -->", max(S))
print ("Min -->", min(S))
# Out:
# S   --> {2, 3, 5, 6, 9, 12}
# Max --> 12
# Min --> 2

# %% [markdown]
# ### 2.13: Searching in the Set

# %%
S = {1, 3, 5, 6, 8, 9}
print ("S            --> ", S)

print ("Is 2 Present -->", 2 in S)
print ("Is 9 Present -->", 9 in S)
# Out:
# S            -->  {1, 3, 5, 6, 8, 9}
# Is 2 Present --> False
# Is 9 Present --> True

# %% [markdown]
# ### 2.14: Operations on Sets - Union, Intersection, Difference, Symmetric  Difference

# %%
a = {'A', 'B', 'E', 'F'}
b = set(["A", "C", "D", "E"])

print ("Set a -->", a)
print ("Set b -->", b)

print("")
print ("Union of a and b          -->", a.union(b))    #ABEFCD
print ("Intersection of a and b   -->", a.intersection(b))  #AE

print("")
print ("Difference a - b          -->", a - b)
print ("Difference a - b          -->", a.difference(b))    #BF
print ("Difference b - a          -->", b - a)
print ("Difference b - a          -->", b.difference(a))     #CD

print("")
print ("Symetric Difference a - b -->", a.symmetric_difference(b))
print ("Symetric Difference b - a -->", b.symmetric_difference(a))
# Out:
# Set a --> {'B', 'E', 'F', 'A'}
# Set b --> {'E', 'C', 'A', 'D'}
#
# Union of a and b          --> {'B', 'F', 'A', 'D', 'C', 'E'}
# Intersection of a and b   --> {'E', 'A'}
#
# Difference a - b          --> {'B', 'F'}
# Difference a - b          --> {'B', 'F'}
# Difference b - a          --> {'C', 'D'}
# Difference b - a          --> {'C', 'D'}
#
# Symetric Difference a - b --> {'B', 'F', 'D', 'C'}
# Symetric Difference b - a --> {'B', 'F', 'D', 'C'}

# %% [markdown]
#                          ordered     indexed         mutable
#
#     List                 ordered     indexed         mutable
#     Tuple                ordered     indexed        immutable
#     DIctionary           ordered     keys-indexed    mutable
#                                      keys -unique
#                                      keys-immutable
#                                      values- any datatype
#
#     Set                  unordered     unindexed         mutable

# %%
a="GKVK"
print(id(a))

a=a+"university"
print(id(a))
# Out:
# 2170356989216
# 2170456428528

# %%
x=10
y=x
print(id(x))
print(id(y))

x=x+20
print(id(x))
# when x is changed a new memory is allocated, means new object is created
print(id(y))
# Out:
# 140728128410696
# 140728128410696
# 140728128411336
# 140728128410696

# %%
s = "Python"
print(id(s))

s = s + "3"
print(id(s))
print(s)

s = "Python"
s[0] = "J"   # ❌ Error
# Out:
# 140731964998672
# 2170451134096
# Python3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 9
#       6 print(s)
#       8 s = "Python"
# ----> 9 s[0] = "J"   # ❌ Error
#
# TypeError: 'str' object does not support item assignment

# %%
s = "Python"
print(s)
print(id(s))
s = "J" + s[1:]
print(s)
print(id(s))
# Out:
# Python
# 140731964998672
# Jython
# 2170450048512

# %%
a = True
print(id(a))

a = False
print(id(a))
# Out:
# 140731965315888
# 140731965315920

# %%
l1=[1,2,3]
print(id(l1))   

l1.append(4)
print(id(l1))   # memory address remains same as list is mutable
# Out:
# 2170448957376
# 2170448957376

# %%
s1={1,2,3}
print(id(s1))

s1.add(4)
print(id(s1))
# Out:
# 2170449995232
# 2170449995232

# %%
d = {"a": 1, "b": 2}
print(id(d))

d["c"] = 3
print(id(d))
# Out:
# 2170455392064
# 2170455392064

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
l1=[1,2,3]
l2=l1
print(id(l1))
print(id(l2))

l1.append(4)
print(l1)
print(l2)

print(id(l1))
print(id(l2))
# Out:
# 2170448493760
# 2170448493760
# [1, 2, 3, 4]
# [1, 2, 3, 4]
# 2170448493760
# 2170448493760

# %%
l1=[1,2,3]
l2=l1
print(id(l1))
print(id(l2))

l1[2]=4
print(l1)
print(l2)

print(id(l1))
print(id(l2))
# Out:
# 2170448929024
# 2170448929024
# [1, 2, 4]
# [1, 2, 4]
# 2170448929024
# 2170448929024

# %%
s1={1,2,3}
s2=s1
print(id(s1))
print(id(s2))

s1.add(4)
print(s1)
print(s2)

print(id(s1))
print(id(s2))
# Out:
# 2170449992768
# 2170449992768
# {1, 2, 3, 4}
# {1, 2, 3, 4}
# 2170449992768
# 2170449992768

# %%
d = {"a": 1, "b": 2}
print(id(d))

d["c"] = 3
print(id(d))
# Out:
# 2170455890880
# 2170455890880

# %%
#tuple
t1=(1,2,3)
t2=t1
print(id(t1))
print(id(t2))

t = (1, 2, 3)
t[0] = 10   # ❌ Error
# Out:
# 2170449824064
# 2170449824064
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       5 print(id(t2))
#       7 t = (1, 2, 3)
# ----> 8 t[0] = 10   # ❌ Error
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1=t1+(4,)
print(t1)
print(t2)

print(id(t1))
print(id(t2))

# %%
In Python, a set is mutable. 
However, it's important to note that the elements contained within the set must be of an immutable data type

# %%
In Python, the mutability or immutability of a data type refers to 
whether the object's state can be modified after it is created. '
'Here's a brief overview of common data types and their mutability:

Mutable:

List (list): Lists are mutable. You can modify, add, or remove elements after the list is created.
Dictionary (dict): Dictionaries are mutable. You can add, remove, or update key-value pairs after the dictionary is created.
Set (set): Sets are mutable. You can add and remove elements from a set after it is created.
Immutable:

Tuple (tuple): Tuples are immutable. Once a tuple is created, you cannot modify its elements.
String (str): Strings are immutable. You cannot change the characters in a string after it is created.
Integer (int): Integers are immutable. The value of an integer cannot be changed after it is created.
Float (float): Floats are immutable. The value of a float cannot be changed after it is created.
Boolean (bool): Booleans are immutable. Their values are True or False, and they cannot be modified.
Note:

Immutability provides certain advantages, such as hashability (useful in sets and dictionary keys)
and safer sharing of objects in concurrent programming.
Tuples can contain mutable objects (e.g., lists), 
but the tuple itself remains immutable (the reference to the mutable object doesn't change).
Some built-in types, like frozenset, are explicitly designed to be immutable sets.
User-defined classes can be designed as mutable or immutable based on how they are implemented.
