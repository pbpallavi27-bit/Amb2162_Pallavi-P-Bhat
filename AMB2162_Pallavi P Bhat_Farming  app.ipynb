# %% [markdown]
# **AMB2162_Pallavi P Bhat**

# %% [markdown]
# ## **FARMING APP**

# %%
print(" WELCOME TO FARM GAME :)")
print("CHOOSE THE OPTION FOR YOUR ACTIONS (enter only the number) ")
print("1.PLANT THE CROP \n2.WATER THE CROPS \n3.HARVEST THE CROP \n4.EXIT")

crops=0
points=0

while(True):
  ch=int(input("\nCHOOSE YOUR ACTION"))
  if ch==1:
    crops+=1
    print("\nyou have planted the crop")
  elif ch==2 and crops>=1:
       print("\nwater your crops")
  elif ch==3 and crops>=1:
        print("/nyou can harvest ")

  elif ch==4:
    print('exit')
    print("points=",10*crops)
    break

  else:
   print("\nplease plant the crop")
# Out:
#  WELCOME TO FARM GAME :)
# CHOOSE THE OPTION FOR YOUR ACTIONS (enter only the number)
# 1.PLANT THE CROP
# 2.WATER THE CROPS
# 3.HARVEST THE CROP
# 4.EXIT
#
# CHOOSE YOUR ACTION3
#
# please plant the crop
#
# CHOOSE YOUR ACTION1
#
# you have planted the crop
#
# CHOOSE YOUR ACTION2
#
# water your crops
#
# CHOOSE YOUR ACTION2
#
# water your crops
#
# CHOOSE YOUR ACTION2
#
# water your crops
#
# CHOOSE YOUR ACTION3
# /nyou can harvest
#
# CHOOSE YOUR ACTION3
# /nyou can harvest
#
# CHOOSE YOUR ACTION4
# exit
# points= 10

# %%
print(" WELCOME TO FARM GAME :)")
print("CHOOSE THE OPTION FOR YOUR ACTIONS (enter only the number) ")
print("1.PLANT THE CROP \n2.WATER THE CROPS \n3.HARVEST THE CROP \n4.EXIT")

crops=0
points=0

while(True):
  ch=int(input("\nCHOOSE YOUR ACTION"))
  if ch==1:
    crops+=1
    print("\nyou have planted the crop")
  elif ch==2 and crops>=1:
       print("\nwater your crops")
  elif ch==3 and crops>=1:
        print("\nyep!! you can harvest (｡˃ ᵕ ˂ ) ")

  elif ch==4:
    print('exit')
    print("points=",10*crops)
    break

  else:
   print("\nplease plant the crop .✦ ݁˖")
# Out:
#  WELCOME TO FARM GAME :)
# CHOOSE THE OPTION FOR YOUR ACTIONS (enter only the number)
# 1.PLANT THE CROP
# 2.WATER THE CROPS
# 3.HARVEST THE CROP
# 4.EXIT
#
# CHOOSE YOUR ACTION1
#
# you have planted the crop
#
# CHOOSE YOUR ACTION2
#
# water your crops
#
# CHOOSE YOUR ACTION3
#
# yep!! you can harvest (｡˃ ᵕ ˂ )
#
# CHOOSE YOUR ACTION4
# exit
# points= 10

# %%
from functools import total_ordering
fish_dict={"catla":0,"rohu":0,"mrigal":0,"mackreal":0,"crab":0}
price={"catla":20,"rohu":32,"mrigal":26,"mackreal":78,"crab":121}
rohu=0
catla=0
mrigal=0
mackreal=0
crab=0
inventory={"rohu":rohu ,"catla":catla ,"mrigal":mrigal ,"crab":crab ,"mackreal":mackreal}
while(True):
 ch=int(input("enter the course of action you would like to perform "))

 if ch==1:
   print("you opted for fishing ")
   # The 'random' module was not imported. Importing it here.
   import random
   # Corrected typo from fis_dict to fish_dict
   # Also, ensure 'fis_dict' is defined before using if 'fish_dict' is not the intended source.
   # Assuming 'fis_dict' from cell iVmp_7lvJFgC was meant to be used for catching.
   # If 'fish_dict' (the one initialized above with 0 values) is intended, it needs non-zero values for random.choice.
   # For now, let's use the 'fis_dict' from cell iVmp_7lvJFgC if it's the source for fish types to catch.
   # If not, the user should define it or use a different source for random fish.
   # For a minimal fix, I'll assume 'fis_dict' from the other cell is the source.
   # However, to make this cell self-contained and fix the error, I will define a temporary 'fishing_options' here if 'fis_dict' is not universally available.
   # Based on the kernel state, 'fis_dict' is defined as {'catla': 12, 'rohu': 12, 'mrigal': 25}.
   # Let's use it, ensuring 'random' is imported.
   random_fish=random.choice(list(fis_dict.keys()))
   print(" hurray!! you caught",random_fish,"≽^•⩊•^≼")
   if random_fish=="rohu":
    rohu+=1
   elif random_fish=="catla":
    catla+=1
   elif random_fish=="mackreal":
    mackreal+=1
   elif random_fish=="crab":
    crab+=1
   else:
    mrigal+=1



 elif ch==2:
  print("you chose to see your inventory")
  # Recreate inventory to reflect updated individual fish counts
  inventory={"rohu":rohu ,"catla":catla ,"mrigal":mrigal ,"crab":crab ,"mackreal":mackreal}
  print(inventory)

#selling fishes
 elif ch==3:
  print("you chose to sell your fishes ")
  # Ensure inventory is up-to-date before selling
  inventory={"rohu":rohu ,"catla":catla ,"mrigal":mrigal ,"crab":crab ,"mackreal":mackreal}

  if sum(inventory.values()) == 0:
      print("no fish to sell")
  else:
    print("Your current inventory:")
    for fish_type, count in inventory.items():
        if count > 0:
            print(f"  - {fish_type}: {count}")

    sell_fish_type = input("Which fish would you like to sell? ").lower() # Get fish type to sell

    # Check if the fish type is valid and available in inventory
    if sell_fish_type in inventory and inventory[sell_fish_type] > 0:
        # Check if a price is defined for the fish
        if sell_fish_type in price:
            fish_price = price[sell_fish_type]

            # Decrease count in inventory
            inventory[sell_fish_type] -= 1

            # Update individual fish variables to keep them in sync
            if sell_fish_type == "rohu":
                rohu = inventory[sell_fish_type]
            elif sell_fish_type == "catla":
                catla = inventory[sell_fish_type]
            elif sell_fish_type == "mrigal":
                mrigal = inventory[sell_fish_type]
            elif sell_fish_type == "mackreal":
                mackreal = inventory[sell_fish_type]
            elif sell_fish_type == "crab":
                crab = inventory[sell_fish_type]

            print(f"You sold one {sell_fish_type} for {fish_price} coins. You now have {inventory[sell_fish_type]} {sell_fish_type}(s).")
        else:
            print(f"Sorry, there's no price defined for {sell_fish_type}.")
    else:
        print(f"You don't have any {sell_fish_type} to sell or that's not a valid fish type.")


 elif ch==4:
   print("exit the process")
   break
 else:
  print("please enter valid option")
# Out:
# enter the course of action you would like to perform 1
# you opted for fishing
#  hurray!! you caught mrigal ≽^•⩊•^≼
# enter the course of action you would like to perform 2
# you chose to see your inventory
# {'rohu': 0, 'catla': 0, 'mrigal': 1, 'crab': 0, 'mackreal': 0}
# enter the course of action you would like to perform 3
# you chose to sell your fishes
# Your current inventory:
#   - mrigal: 1
# Which fish would you like to sell? mrigal
# You sold one mrigal for 26 coins. You now have 0 mrigal(s).

# %%
from functools import total_ordering
fish_dict={"catla":0,"rohu":0,"mrigal":0,"mackreal":0,"crab":0}
price={"catla":20,"rohu":32,"mrigal":26,"mackreal":78,"crab":121}
rohu=0
catla=0
mrigal=0
mackreal=0
crab=0
inventory={"rohu":rohu ,"catla":catla ,"mrigal":mrigal ,"crab":crab ,"mackreal":mackreal}
while(True):
 ch=int(input("enter the course of action you would like to perform "))

 if ch==1:
   print("you opted for fishing ")
   random_fish=random_fish=random.choice(list(fish_dict.keys()))
   print(" hurray!! you caught",random_fish,"≽^•⩊•^≼")
   if random_fish=="rohu":
    rohu+=1
   elif random_fish=="catla":
    catla+=1
   elif random_fish=="mackreal":
    mackreal+=1
   elif random_fish=="crab":
    crab+=1
   else:
    mrigal+=1



 elif ch==2:
  print("you chose to see your inventory")
  inventory={"rohu":rohu ,"catla":catla ,"mrigal":mrigal ,"crab":crab,"mackreal":mackreal}
  print(inventory)

#selling fishes
 elif ch==3:
  print("you chose to sell your fishes ")
  if inventory=={}:
      print("no fish to sell")
  else:
    print("which fish would to like to sell")
    maxkey=max(inventory.keys())
    print("you have maximum of ",maxkey)
    s=input("sell")
    total_earnings=0
    r=0
    c=0
    m=0
    mac=0
    cr=0
    rs=20
    cs=50
    ms=70
    macs=36
    crs=121
    vs=sum(inventory.values())
  while(True):
     if vs==0:
      print("you have no fishes left to sell")
      break
     elif s=="rohu" and inventory.get["rohu"]>0:
       r+=1
       inventory.get["rohu"]=-1
       print("money from rohu",r*rs)
       vs=-1
     elif s=="catla" and inventory.get["catla"]>0:
       c+=1
       print("money from rohu",c*cs)
       inventory.get["ctala"]=-1
       vs-=1
     elif m=="mrigal" and inventory.get["mrigal"]>0:
       m+=1
       inventory.get["mrigal"]=-1

       print("money from mrigal",m*ms)

     elif m=="mackreal" and inventory.get["mackreal"]>0:
       m+=1
       inventory.get["mackreal"]=-1

       print("money from mackreal",mac*macs)
     elif m=="crab" and inventory.get["crab"]>0:
       m+=1
       inventory.get["crab"]=-1

       print("money from crab",cr*crs)

     else:
       total_earnings =(r*rs+m*ms+c*ms+mac*macs+cr*crs)
       print("total money",total_earnings)
       break




 elif ch==4:
   print("exit the process")
   break
 else:
  print("please enter valid option")
# Out:
# enter the course of action you would like to perform 1
# you opted for fishing
#  hurray!! you caught mackreal ≽^•⩊•^≼
# enter the course of action you would like to perform 1
# you opted for fishing
#  hurray!! you caught catla ≽^•⩊•^≼
# enter the course of action you would like to perform 1
# you opted for fishing
#  hurray!! you caught rohu ≽^•⩊•^≼
# enter the course of action you would like to perform 2
# you chose to see your inventory
# {'rohu': 1, 'catla': 1, 'mrigal': 0, 'crab': 0, 'mackreal': 1}
# enter the course of action you would like to perform 3
# you chose to sell your fishes
# which fish would to like to sell
# you have maximum of  rohu
# sellrohu
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2316539051.py in <cell line: 0>()
#      59       print("you have no fishes left to sell")
#      60       break
# ...
